# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# read in data
data = pd.read_csv(r"C:\Users\lawsonsa\Downloads\archive\star_classification.csv")

# split data into training and testing sets
X = data.drop('class', axis=1)
y = data['class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# scale data
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# create dictionary of models
models = {'Naive Bayes': GaussianNB(), 
          'SVM': SVC(),
          'KNN': KNeighborsClassifier(),
          'SVM': SVC(),
          'Decision Tree': DecisionTreeClassifier(),
          'Random Forest': RandomForestClassifier(),
          'AdaBoost': AdaBoostClassifier(),
          'Gradient Boosting': GradientBoostingClassifier(),
          'Bagging': BaggingClassifier(),
          'Logistic Regression': LogisticRegression(),
          'SGD': SGDClassifier(),
          'MLP': MLPClassifier()}

# create dictionary of models with parameters to tune
'''
params = {'KNN': {'n_neighbors': [1, 3, 5, 7, 9, 11, 13, 15]},
          'Naive Bayes': {},
          'SVM': {'C': [0.1, 1, 10, 100, 1000], 'gamma': [1, 0.1, 0.01, 0.001, 0.0001]},
          'Decision Tree': {'max_depth': [1, 5, 10, 20, 50, 100], 'min_samples_split': [2, 5, 10, 20]},
          'Random Forest': {'n_estimators': [1, 5, 10, 20, 50, 100], 'max_depth': [1, 5, 10, 20, 50, 100], 'min_samples_split': [2, 5, 10, 20]},
          'AdaBoost': {'n_estimators': [1, 5, 10, 20, 50, 100]},
          'Gradient Boosting': {'n_estimators': [1, 5, 10, 20, 50, 100], 'max_depth': [1, 5, 10, 20, 50, 100], 'min_samples_split': [2, 5, 10, 20]},
          'Bagging': {'n_estimators': [1, 5, 10, 20, 50, 100]},
          'Logistic Regression': {'C': [0.1, 1, 10, 100, 1000]},
          'SGD': {'loss': ['hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron'], 'penalty': ['l1', 'l2', 'elasticnet']},
          'MLP': {'hidden_layer_sizes': [10, 50, 100], 'activation': ['identity', 'logistic', 'tanh', 'relu']}}
'''
params = {'KNN': {},
          'Naive Bayes': {},
          'SVM': {},
          'Decision Tree': {},
          'Random Forest': {},
          'AdaBoost': {},
          'Gradient Boosting': {},
          'Bagging': {},
          'Logistic Regression': {},
          'SGD': {},
          'MLP': {}}


# create dictionary of tuned models
tuned_models = {}

# loop through models
for model in models:
    # tune model
    clf = GridSearchCV(models[model], params[model], cv=5, verbose=3)
    # fit model
    clf.fit(X_train, y_train)
    # save model
    tuned_models[model] = clf
    # print results
    print(model)
    print('Best Score: ' + str(clf.best_score_))
    print('Best Parameters: ' + str(clf.best_params_))
    print('\n')
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..................................., score=0.886 total time=   0.0s
# [CV 2/5] END ..................................., score=0.710 total time=   0.0s
# [CV 3/5] END ..................................., score=0.709 total time=   0.0s
# [CV 4/5] END ..................................., score=0.708 total time=   0.0s
# [CV 5/5] END ..................................., score=0.701 total time=   0.0s
# Naive Bayes
# Best Score: 0.7426625
# Best Parameters: {}
#
#
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..................................., score=0.956 total time= 1.2min
# [CV 2/5] END ..................................., score=0.954 total time= 1.1min
# [CV 3/5] END ..................................., score=0.957 total time= 1.1min
# [CV 4/5] END ..................................., score=0.953 total time= 1.1min
# [CV 5/5] END ..................................., score=0.956 total time= 1.1min
# SVM
# Best Score: 0.9553375000000001
# Best Parameters: {}
#
#
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..................................., score=0.902 total time=  16.5s
# [CV 2/5] END ..................................., score=0.891 total time=  15.8s
# [CV 3/5] END ..................................., score=0.897 total time=  15.7s
# [CV 4/5] END ..................................., score=0.898 total time=  15.4s
# [CV 5/5] END ..................................., score=0.896 total time=  15.8s
# KNN
# Best Score: 0.8966625
# Best Parameters: {}
#
#
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..................................., score=0.965 total time=   1.2s
# [CV 2/5] END ..................................., score=0.964 total time=   1.1s
# [CV 3/5] END ..................................., score=0.966 total time=   1.2s
# [CV 4/5] END ..................................., score=0.965 total time=   1.2s
# [CV 5/5] END ..................................., score=0.965 total time=   1.2s
# Decision Tree
# Best Score: 0.9649625000000001
# Best Parameters: {}
#
#
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..................................., score=0.978 total time=  16.6s
# [CV 2/5] END ..................................., score=0.977 total time=  16.6s
# [CV 3/5] END ..................................., score=0.979 total time=  16.6s
# [CV 4/5] END ..................................., score=0.977 total time=  16.8s
# [CV 5/5] END ..................................., score=0.980 total time=  16.7s
# Random Forest
# Best Score: 0.9783249999999999
# Best Parameters: {}
#
#
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..................................., score=0.765 total time=   8.9s
# [CV 2/5] END ..................................., score=0.663 total time=   8.9s
# [CV 3/5] END ..................................., score=0.691 total time=   8.7s
# [CV 4/5] END ..................................., score=0.691 total time=   8.8s
# [CV 5/5] END ..................................., score=0.621 total time=   8.8s
# AdaBoost
# Best Score: 0.686175
# Best Parameters: {}
#
#
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..................................., score=0.976 total time= 1.2min
# [CV 2/5] END ..................................., score=0.975 total time= 1.2min
# [CV 3/5] END ..................................., score=0.977 total time= 1.2min
# [CV 4/5] END ..................................., score=0.975 total time= 1.2min
# [CV 5/5] END ..................................., score=0.978 total time= 1.2min
# Gradient Boosting
# Best Score: 0.976275
# Best Parameters: {}
#
#
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..................................., score=0.977 total time=   6.9s
# [CV 2/5] END ..................................., score=0.976 total time=   6.5s
# [CV 3/5] END ..................................., score=0.979 total time=   6.6s
# [CV 4/5] END ..................................., score=0.977 total time=   6.9s
# [CV 5/5] END ..................................., score=0.978 total time=   6.9s
# Bagging
# Best Score: 0.9775
# Best Parameters: {}
#
#
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\lawsonsa\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END ..................................., score=0.957 total time=   2.0s
# C:\Users\lawsonsa\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END ..................................., score=0.955 total time=   2.0s
# C:\Users\lawsonsa\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5] END ..................................., score=0.957 total time=   1.9s
# C:\Users\lawsonsa\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END ..................................., score=0.954 total time=   1.9s
# C:\Users\lawsonsa\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END ..................................., score=0.956 total time=   1.8s
# C:\Users\lawsonsa\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression
# Best Score: 0.9558375
# Best Parameters: {}
#
#
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..................................., score=0.913 total time=   0.2s
# [CV 2/5] END ..................................., score=0.909 total time=   0.3s
# [CV 3/5] END ..................................., score=0.916 total time=   0.2s
# [CV 4/5] END ..................................., score=0.911 total time=   0.2s
# [CV 5/5] END ..................................., score=0.910 total time=   0.3s
# SGD
# Best Score: 0.9119125
# Best Parameters: {}
#
#
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..................................., score=0.970 total time=  44.3s
# C:\Users\lawsonsa\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 2/5] END ..................................., score=0.970 total time=  47.3s
# [CV 3/5] END ..................................., score=0.972 total time=  38.1s
# C:\Users\lawsonsa\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 4/5] END ..................................., score=0.971 total time=  47.3s
# [CV 5/5] END ..................................., score=0.973 total time=  29.6s
# MLP
# Best Score: 0.9712
# Best Parameters: {}

# %%
import seaborn as sns

# create dictionary of predictions
predictions = {}

# loop through models
for model in tuned_models:
    # predict classes
    predictions[model] = tuned_models[model].predict(X_test)

# create dictionary of scores
scores = {}

# loop through models
for model in predictions:
    # save accuracy
    scores[model] = accuracy_score(y_test, predictions[model])

# create dictionary of confusion matrices
confusion = {}

# loop through models
for model in predictions:
    # create confusion matrix
    confusion[model] = confusion_matrix(y_test, predictions[model])

# create dataframe of scores
scores = pd.DataFrame(scores.items(), columns=['model', 'score'])

# create dataframe of confusion matrices
confusion = pd.DataFrame(confusion.items(), columns=['model', 'confusion_matrix'])

# plot barplot of scores
sns.set(rc = {'figure.figsize':(15,8)})
sns.barplot(x='model', y='score', data=scores)
plt.show()

# %%
scores
# Out:
#                   model    score
# 0           Naive Bayes  0.71020
# 1                   SVM  0.95615
# 2                   KNN  0.89785
# 3         Decision Tree  0.96495
# 4         Random Forest  0.97755
# 5              AdaBoost  0.61105
# 6     Gradient Boosting  0.97595
# 7               Bagging  0.97730
# 8   Logistic Regression  0.95385
# 9                   SGD  0.91195
# 10                  MLP  0.97025

# %%
# plot confusion matrix heatmap
for index in confusion.index:
    print(f' Heatmap for {confusion.iloc[index, 0]}')
    sns.heatmap(confusion.iloc[index, 1], annot=True, cmap='Blues')
    plt.show()
# Out:
#  Heatmap for Naive Bayes
#  Heatmap for SVM
#  Heatmap for KNN
#  Heatmap for Decision Tree
#  Heatmap for Random Forest
#  Heatmap for AdaBoost
#  Heatmap for Gradient Boosting
#  Heatmap for Bagging
#  Heatmap for Logistic Regression
#  Heatmap for SGD
#  Heatmap for MLP
